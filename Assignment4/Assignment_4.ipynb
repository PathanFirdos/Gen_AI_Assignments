# %%
# !pip install transformers torch

# %%
from transformers import pipeline

# Load pre-trained question answering model
qa_bot = pipeline(
    "question-answering",
    model="distilbert-base-cased-distilled-squad"
)

# Context for answering questions
context = """
Artificial Intelligence is the simulation of human intelligence in machines.
Machine Learning is a subset of Artificial Intelligence that allows systems
to learn from data. Deep Learning is a subset of Machine Learning that uses
neural networks with multiple layers.
"""

print("Question Answering Chatbot")
print("Type 'exit' to stop\n")

while True:
    question = input("Enter your question: ")

    if question.lower() == "exit":
        break

    answer = qa_bot(question=question, context=context)
    print("Answer:", answer["answer"])
# Out:
# Device set to use cpu
# Question Answering Chatbot
# Type 'exit' to stop
#
# Enter your question: who are you
# Answer: Machine Learning
# Enter your question: what is machine learning
# Answer: allows systems
# to learn from data
# Enter your question: differenec between machine learning and Genrative Ai
# Answer: Machine Learning is a subset of Artificial Intelligence
# Enter your question: what is generatve AI
# Answer: Machine Learning
# Enter your question: what is deep learning
# Answer: a subset of Machine Learning that uses
# neural networks with multiple layers
# Enter your question: exit
